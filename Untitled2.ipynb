# %%
import pandas as pd

# %%
train = pd.read_csv('test.csv', encoding='utf-8')

# %%
train
# Out:
#          no                            모델명           연월      연식   연료   주행거리  \
# 0     11769       제네시스 GV80 3.0 디젤 AWD 5인승        20/04  2020.0   디젤   8천km
# 1     11770  쉐보레 어메이징 뉴 크루즈 2.0 디젤 LT 디럭스팩        15/05  2015.0   디젤   9만km
# 2     11771               현대 그랜져HG 240 럭셔리        12/07  2012.0  가솔린  11만km
# 3     11772                   기아 더 뉴 모닝 밴   15/04(16년형)  2016.0  가솔린   2만km
# 4     11773       쉐보레 더 넥스트 스파크 1.0 LT 플러스  16/07(17년형)  2017.0  가솔린   1만km
# ...     ...                            ...          ...     ...  ...    ...
# 5784  17553          현대 그랜저 뉴 럭셔리 Q270 럭셔리  08/05(09년형)  2009.0  가솔린  11만km
# 5785  17554     기아 더 프레스티지 K7 3.0 GDI 노블레스  11/03(12년형)  2012.0  가솔린  11만km
# 5786  17555          현대 뉴 투스카니 2.0 GTS 고급형        07/08  2007.0  가솔린  15만km
# 5787  17556            현대 제네시스 쿠페 380 GT P  09/05(10년형)  2010.0  가솔린   7만km
# 5788  17557          현대 뉴 에쿠스 VS 380 프레스티지  14/03(15년형)  2015.0  가솔린   7만km
#
#       인승  최대출력(마력)   기통  최대토크(kgm) 구동방식 자동수동 국산/수입
# ...

# %%
for i, row in train.iterrows():
    if '어울림모터스' in row['모델명'].split():
        print("in!")
# Out:
# in!

# %%
train['연료'].unique()
# Out:
# array(['디젤', '가솔린', 'LPG', '가솔린/LPG겸용', '가솔린+전기', 'LPG+전기', '기타', 'CNG',
#        '전기', '가솔린/CNG겸용'], dtype=object)
