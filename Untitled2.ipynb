# %%
import pandas as pd

# %%
train = pd.read_csv('train_clean.csv', encoding='utf-8')

# %%
train
# Out:
#                                  모델명      연식  최대출력(마력)   기통  최대토크(kgm)  \
# 0        기아 더 뉴 K7 2.4 GDI 프레스티지 스페셜  2013.0     201.0  4.0       25.5
# 1               현대 그랜져HG 220 디젤 프리미엄  2015.0     202.0  4.0       45.0
# 2            쌍용 뉴카이런 2.0 LV5 2WD 고급형  2008.0     151.0  4.0       33.8
# 3         기아 오피러스 프리미엄 GH270 스페셜 럭셔리  2011.0     195.0  6.0       25.6
# 4              기아 K7 VG350 노블레스 프리미엄  2010.0     290.0  6.0       34.5
# ...                              ...     ...       ...  ...        ...
# 8371      제네시스 G90 5.0 GDi AWD 프레스티지  2019.0     425.0  8.0       53.0
# 8372             현대 제네시스 쿠페 200 터보 P  2009.0     210.0  4.0       30.5
# 8373  제네시스 EQ900 3.3 T-GDi AWD 프레스티지  2016.0     370.0  6.0       52.0
# 8374    제네시스 EQ900 5.0 GDi AWD 프레스티지  2016.0     425.0  8.0       53.0
# 8375    제네시스 EQ900 5.0 GDi AWD 프레스티지  2016.0     425.0  8.0       53.0
#
#       신차가(만원)    가격(만원)    주행거리  구동방식
# 0      3141.0    1870.0   40000     0
# ...
