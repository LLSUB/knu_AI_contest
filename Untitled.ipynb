# %%
import pandas as pd

# %%
train = pd.read_csv('train2.csv', encoding='utf-8')

# %%
train
# Out:
#           no                                모델명           연월      연식   연료  \
# 0          0        기아 더 뉴 K7 2.4 GDI 프레스티지 스페셜  12/12(13년형)  2013.0  가솔린
# 1          1          현대 YF쏘나타 2.0 Y20 LPi 프리미어        10/03  2010.0  LPG
# 2          2               현대 그랜져HG 220 디젤 프리미엄  14/09(15년형)  2015.0   디젤
# 3          3            쌍용 뉴카이런 2.0 LV5 2WD 고급형  07/06(08년형)  2008.0   디젤
# 4          4  현대 뉴스타렉스 점보 밴 TCI 3인승 GX 윈도우밴 일반형        04/03  2004.0   디젤
# ...      ...                                ...          ...     ...  ...
# 11735  11764                현대 제네시스 쿠페 200 터보 P        09/07  2009.0  가솔린
# 11736  11765                   어울림모터스 스피라 S 2.7        12/06  2012.0  가솔린
# 11737  11766     제네시스 EQ900 3.3 T-GDi AWD 프레스티지        16/05  2016.0  가솔린
# 11738  11767       제네시스 EQ900 5.0 GDi AWD 프레스티지        16/01  2016.0  가솔린
# 11739  11768       제네시스 EQ900 5.0 GDi AWD 프레스티지  15/12(16년형)  2016.0  가솔린
#
#         인승  최대출력(마력)   기통  최대토크(kgm) 구동방식 자동수동 국산/수입  신차가(만원)    가격(만원)  \
# 0      NaN     201.0  4.0       25.5   FF  NaN    국산   3141.0    1870.0
# 1      NaN     157.0  NaN       20.0   FF  NaN    국산      NaN     700.0
# 2      NaN     202.0  4.0       45.0   FF  NaN    국산   3389.0    2990.0
# 3      NaN     151.0  4.0       33.8   FR  NaN    국산   2499.0     420.0
# 4      3.0     103.0  NaN       24.0   FR   수동    국산   1445.0     450.0
# ...    ...       ...  ...        ...  ...  ...   ...      ...       ...
# 11735  NaN     210.0  4.0       30.5   FR  NaN    국산   2641.0  111111.0
# 11736  NaN       NaN  NaN        NaN  NaN   수동    국산  10508.0   10500.0
# 11737  NaN     370.0  6.0       52.0  AWD  NaN    국산  10900.0   10000.0
# 11738  NaN     425.0  8.0       53.0  AWD  NaN    국산  11490.0   10300.0
# 11739  NaN     425.0  8.0       53.0  AWD  NaN    국산  11490.0   10800.0
#
#          주행거리
# 0       40000
# 1       90000
# 2       30000
# 3      160000
# 4      160000
# ...       ...
# 11735  110000
# 11736    5000
# 11737     230
# 11738    9000
# 11739    3000
#
# [11740 rows x 15 columns]

# %%
# print(len(train))

# for i in train.columns:
#     print(i)

train['연료'].unique()
# Out:
# array(['가솔린', 'LPG', '디젤', '가솔린/LPG겸용', '전기', '가솔린+전기', '수소', 'LPG+전기',
#        '기타', '가솔린/CNG겸용', 'CNG'], dtype=object)

# %%
# 11740개의 데이터중 10450개가 NaN값 이므로 이 열은 제거한다.  (11/11 10:11)

# cnt = 0
# for i, row in train.iterrows():
#     if pd.isnull(row['자동수동']):
#         cnt += 1
        
# print(cnt)

del train['자동수동']
# Out:
# 10450

# %%
# cnt = 0
# for i, row in train.iterrows():
#     if pd.isnull(row['인승']):
#         cnt += 1
        
# print(cnt)
# print(train['인승'].unique())

del train['인승']

# %%
train
# Out:
#           no                                모델명           연월      연식   연료  \
# 0          0        기아 더 뉴 K7 2.4 GDI 프레스티지 스페셜  12/12(13년형)  2013.0  가솔린
# 1          1          현대 YF쏘나타 2.0 Y20 LPi 프리미어        10/03  2010.0  LPG
# 2          2               현대 그랜져HG 220 디젤 프리미엄  14/09(15년형)  2015.0   디젤
# 3          3            쌍용 뉴카이런 2.0 LV5 2WD 고급형  07/06(08년형)  2008.0   디젤
# 4          4  현대 뉴스타렉스 점보 밴 TCI 3인승 GX 윈도우밴 일반형        04/03  2004.0   디젤
# ...      ...                                ...          ...     ...  ...
# 11735  11764                현대 제네시스 쿠페 200 터보 P        09/07  2009.0  가솔린
# 11736  11765                   어울림모터스 스피라 S 2.7        12/06  2012.0  가솔린
# 11737  11766     제네시스 EQ900 3.3 T-GDi AWD 프레스티지        16/05  2016.0  가솔린
# 11738  11767       제네시스 EQ900 5.0 GDi AWD 프레스티지        16/01  2016.0  가솔린
# 11739  11768       제네시스 EQ900 5.0 GDi AWD 프레스티지  15/12(16년형)  2016.0  가솔린
#
#        최대출력(마력)   기통  최대토크(kgm) 구동방식 국산/수입  신차가(만원)    가격(만원)    주행거리
# 0         201.0  4.0       25.5   FF    국산   3141.0    1870.0   40000
# 1         157.0  NaN       20.0   FF    국산      NaN     700.0   90000
# 2         202.0  4.0       45.0   FF    국산   3389.0    2990.0   30000
# 3         151.0  4.0       33.8   FR    국산   2499.0     420.0  160000
# 4         103.0  NaN       24.0   FR    국산   1445.0     450.0  160000
# ...         ...  ...        ...  ...   ...      ...       ...     ...
# 11735     210.0  4.0       30.5   FR    국산   2641.0  111111.0  110000
# 11736       NaN  NaN        NaN  NaN    국산  10508.0   10500.0    5000
# 11737     370.0  6.0       52.0  AWD    국산  10900.0   10000.0     230
# 11738     425.0  8.0       53.0  AWD    국산  11490.0   10300.0    9000
# 11739     425.0  8.0       53.0  AWD    국산  11490.0   10800.0    3000
#
# [11740 rows x 13 columns]

# %%
train.isnull().sum()
# Out:
# no              0
# 모델명             0
# 연월              0
# 연식              0
# 연료              0
# 최대출력(마력)     1096
# 기통           3042
# 최대토크(kgm)    1195
# 구동방식          932
# 국산/수입           0
# 신차가(만원)      2196
# 가격(만원)          0
# 주행거리            0
# dtype: int64
